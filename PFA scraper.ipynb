# %%
import requests
from bs4 import BeautifulSoup as bs 
import pandas as pd 
import numpy as np

# %%
#get the names of the companies
url='https://en.wikipedia.org/wiki/PFA_Players%27_Player_of_the_Year'
page = requests.get(url)
data=page.content
soup = bs(data, 'html.parser')

players = []
for element in soup.select('table'):
    players.append(element.text.strip())
# Out:
# Winners of the PFA Players' of the Year
#
#
# Year
#
#
#
# Player
# Club
# Also won
# Notes
#
#
# 1973–74
#
# Norman Hunter
# Leeds United
#
#
#
#
# 1974–75
#
# Colin Todd
# Derby County
#
#
#
#
# 1975–76
#
# Pat Jennings
# Tottenham Hotspur
#
# [17]
#
#
# 1976–77
#
# Andy Gray
# Aston Villa
# YPY
# [18]
#
#
# 1977–78
#
# Peter Shilton
# Nottingham Forest
#
#
#
#
# 1978–79
#
# Liam Brady
# Arsenal
#
# [19]
#
#
# 1979–80
#
# Terry McDermott
# Liverpool
# FWA
# [20]
#
#
# 1980–81
#
# John Wark
# Ipswich Town
#
#
#
#
# 1981–82
#
# Kevin Keegan
# Southampton
#
#
#
#
# 1982–83
#
# Kenny Dalglish
# Liverpool
# FWA
#
#
#
# 1983–84
#
# Ian Rush
# Liverpool
# FWA
#
#
#
# 1984–85
#
# Peter Reid
# Everton
#
#
#
#
# 1985–86
#
# Gary Lineker
# Everton
# FWA
#
#
#
# 1986–87
#
# Clive Allen
# Tottenham Hotspur
# FWA
#
#
#
# 1987–88
#
# John Barnes
# Liverpool
# FWA
#
#
#
# 1988–89
#
# Mark Hughes
# Manchester United
#
#
#
#
# 1989–90
#
# David Platt
# Aston Villa
#
#
#
#
# 1990–91
#
# Mark Hughes (2)
# Manchester United
#
# [21]
#
#
# 1991–92
#
# Gary Pallister
# Manchester United
#
#
#
#
# 1992–93
#
# Paul McGrath
# Aston Villa
#
#
#
#
# 1993–94
#
# Eric Cantona
# Manchester United
#
# [22]
#
#
# 1994–95
#
# Alan Shearer
# Blackburn Rovers
# PPS
#
#
#
# 1995–96
#
# Les Ferdinand
# Newcastle United
#
#
#
#
# 1996–97
#
# Alan Shearer (2)
# Newcastle United
#
# [23]
#
#
# 1997–98
#
# Dennis Bergkamp
# Arsenal
# FWA
#
#
#
# 1998–99
#
# David Ginola
# Tottenham Hotspur
# FWA
#
#
#
# 1999–2000
#
# Roy Keane
# Manchester United
# FWA
#
#
#
# 2000–01
#
# Teddy Sheringham
# Manchester United
# FWA
#
#
#
# 2001–02
#
# Ruud van Nistelrooy
# Manchester United
# FPY
#
#
#
# 2002–03
#
# Thierry Henry
# Arsenal
# FWA, FPY
# [24]
#
#
# 2003–04
#
# Thierry Henry (2)
# Arsenal
# FWA, FPY, PPS
# [25]
#
#
# 2004–05
#
# John Terry
# Chelsea
#
#
#
#
# 2005–06
#
# Steven Gerrard
# Liverpool
#
#
#
#
# 2006–07
#
# Cristiano Ronaldo
# Manchester United
# FWA, FPY, YPY, PPS
# [26]
#
#
# 2007–08
#
# Cristiano Ronaldo (2)
# Manchester United
# FWA, FPY, PPS
# [27]
#
#
# 2008–09
#
# Ryan Giggs
# Manchester United
#
# [28]
#
#
# 2009–10
#
# Wayne Rooney
# Manchester United
# FWA, FPY, PPS
# [11]
#
#
# 2010–11
#
# Gareth Bale
# Tottenham Hotspur
#
# [29]
#
#
# 2011–12
#
# Robin van Persie
# Arsenal
# FWA, FPY
# [30]
#
#
# 2012–13
#
# Gareth Bale (2)
# Tottenham Hotspur
# FWA, YPY, PPS
# [31]
#
#
# 2013–14
#
# Luis Suárez
# Liverpool
# FWA, FPY, PPS, FSF
# [32]
#
#
# 2014–15
#
# Eden Hazard
# Chelsea
# FWA, PPS
# [33]
#
#
# 2015–16
#
# Riyad Mahrez
# Leicester City
# FPY
# [34]
#
#
# 2016–17
#
# N'Golo Kanté
# Chelsea
# FWA, PPS
# [35]
#
#
# 2017–18
#
# Mohamed Salah
# Liverpool
# FWA, FPY, PPS, FSF
# [36]
#
#
# 2018–19
#
# Virgil van Dijk
# Liverpool
# PPS, FSF
# [37]
#
#
# 2019–20
#
# Kevin De Bruyne
# Manchester City
# PPS
# [38]
#
#
# 2020–21
#
# Kevin De Bruyne (2)
# Manchester City

# %%
data = players[1]

# %%
cleaned = []
cleaned.append(data.split('\n'))
to_use = cleaned[0]

# %%
for i in range(len(to_use)-1): 
    print(to_use[i])
    if to_use[i] == '': 
        to_use.pop(i)
# Out:
# Winners of the PFA Players' of the Year
# Year
# Player
# Club
# Also won
# Notes
# 1973–74
# Norman Hunter
# Leeds United
# 1974–75
# Colin Todd
# Derby County
# 1975–76
# Pat Jennings
# Tottenham Hotspur
# [17]
# 1976–77
# Andy Gray
# Aston Villa
# YPY
# [18]
# 1977–78
# Peter Shilton
# Nottingham Forest
# 1978–79
# Liam Brady
# Arsenal
# [19]
# 1979–80
# Terry McDermott
# Liverpool
# FWA
# [20]
# 1980–81
# John Wark
# Ipswich Town
# 1981–82
# Kevin Keegan
# Southampton
# 1982–83
# Kenny Dalglish
# Liverpool
# FWA
# 1983–84
# Ian Rush
# Liverpool
# FWA
# 1984–85
# Peter Reid
# Everton
# 1985–86
# Gary Lineker
# Everton
# FWA
# 1986–87
# Clive Allen
# Tottenham Hotspur
# FWA
# 1987–88
# John Barnes
# Liverpool
# FWA
# 1988–89
# Mark Hughes
# Manchester United
# 1989–90
# David Platt
# Aston Villa
# 1990–91
# Mark Hughes (2)
# Manchester United
# [21]
# 1991–92
# Gary Pallister
# Manchester United
# 1992–93
# Paul McGrath
# Aston Villa
# 1993–94
# Eric Cantona
# Manchester United
# [22]
# 1994–95
# Alan Shearer
# Blackburn Rovers
# PPS
# 1995–96
# Les Ferdinand
# Newcastle United
# 1996–97
# Alan Shearer (2)
# Newcastle United
# [23]
# 1997–98
# Dennis Bergkamp
# Arsenal
# FWA
# 1998–99
# David Ginola
# Tottenham Hotspur
# FWA
# 1999–2000
# Roy Keane
# Manchester United
# FWA
# 2000–01
# Teddy Sheringham
# Manchester United
# FWA
# 2001–02
# Ruud van Nistelrooy
# Manchester United
# FPY
# 2002–03
# Thierry Henry
# Arsenal
# FWA, FPY
# [24]
# 2003–04
# Thierry Henry (2)
# Arsenal
# FWA, FPY, PPS
# [25]
# 2004–05
# John Terry
# Chelsea
# 2005–06
# Steven Gerrard
# Liverpool
# 2006–07
# Cristiano Ronaldo
# Manchester United
# FWA, FPY, YPY, PPS
# [26]
# 2007–08
# Cristiano Ronaldo (2)
# Manchester United
# FWA, FPY, PPS
# [27]
# 2008–09
# Ryan Giggs
# Manchester United
# [28]
# 2009–10
# Wayne Rooney
# Manchester United
# FWA, FPY, PPS
# [11]
# 2010–11
# Gareth Bale
# Tottenham Hotspur
# [29]
# 2011–12
# Robin van Persie
# Arsenal
# FWA, FPY
# [30]
# 2012–13
# Gareth Bale (2)
# Tottenham Hotspur
# FWA, YPY, PPS
# [31]
# 2013–14
# Luis Suárez
# Liverpool
# FWA, FPY, PPS, FSF
# [32]
# 2014–15
# Eden Hazard
# Chelsea
# FWA, PPS
# [33]
# 2015–16
# Riyad Mahrez
# Leicester City
# FPY
# [34]
# 2016–17
# N'Golo Kanté
# Chelsea
# FWA, PPS
# [35]
# 2017–18
# Mohamed Salah
# Liverpool
# FWA, FPY, PPS, FSF
# [36]
# 2018–19
# Virgil van Dijk
# Liverpool
# PPS, FSF
# [37]
# 2019–20
# Kevin De Bruyne
# Manchester City
# PPS
# [38]
# 2020–21
# Kevin De Bruyne (2)

# %%
to_use
# Out:
# ["Winners of the PFA Players' of the Year",
#  'Year',
#  'Player',
#  'Club',
#  'Also won',
#  'Notes',
#  '1973–74',
#  'Norman Hunter',
#  'Leeds United',
#  '1974–75',
#  'Colin Todd',
#  'Derby County',
#  '1975–76',
#  'Pat Jennings',
#  'Tottenham Hotspur',
#  '[17]',
#  '1976–77',
#  'Andy Gray',
#  'Aston Villa',
#  'YPY',
#  '[18]',
#  '1977–78',
#  'Peter Shilton',
#  'Nottingham Forest',
#  '1978–79',
#  'Liam Brady',
#  'Arsenal',
#  '[19]',
#  '1979–80',
#  'Terry McDermott',
#  'Liverpool',
#  'FWA',
#  '[20]',
#  '1980–81',
#  'John Wark',
#  'Ipswich Town',
#  '1981–82',
#  'Kevin Keegan',
#  'Southampton',
#  '1982–83',
#  'Kenny Dalglish',
#  'Liverpool',
#  'FWA',
#  '1983–84',
#  'Ian Rush',
#  'Liverpool',
#  'FWA',
#  '1984–85',
#  'Peter Reid',
#  'Everton',
#  '1985–86',
#  'Gary Lineker',
#  'Everton',
#  'FWA',
#  '1986–87',
#  'Clive Allen',
#  'Tottenham Hotspur',
#  'FWA',
#  '1987–88',
#  'John Barnes',
#  'Liverpool',
#  'FWA',
#  '1988–89',
#  'Mark Hughes',
#  'Manchester United',
#  '1989–90',
#  'David Platt',
#  'Aston Villa',
#  '1990–91',
#  'Mark Hughes (2)',
#  'Manchester United',
#  '[21]',
#  '1991–92',
#  'Gary Pallister',
#  'Manchester United',
#  '1992–93',
#  'Paul McGrath',
#  'Aston Villa',
#  '1993–94',
#  'Eric Cantona',
#  'Manchester United',
#  '[22]',
#  '1994–95',
#  'Alan Shearer',
#  'Blackburn Rovers',
#  'PPS',
#  '1995–96',
#  'Les Ferdinand',
#  'Newcastle United',
#  '1996–97',
#  'Alan Shearer (2)',
#  'Newcastle United',
#  '[23]',
#  '1997–98',
#  'Dennis Bergkamp',
#  'Arsenal',
#  'FWA',
#  '1998–99',
#  'David Ginola',
#  'Tottenham Hotspur',
#  'FWA',
#  '1999–2000',
#  'Roy Keane',
#  'Manchester United',
#  'FWA',
#  '2000–01',
#  'Teddy Sheringham',
#  'Manchester United',
#  'FWA',
#  '2001–02',
#  'Ruud van Nistelrooy',
#  'Manchester United',
#  'FPY',
#  '2002–03',
#  'Thierry Henry',
#  'Arsenal',
#  'FWA, FPY',
#  '[24]',
#  '2003–04',
#  'Thierry Henry (2)',
#  'Arsenal',
#  'FWA, FPY, PPS',
#  '[25]',
#  '2004–05',
#  'John Terry',
#  'Chelsea',
#  '2005–06',
#  'Steven Gerrard',
#  'Liverpool',
#  '2006–07',
#  'Cristiano Ronaldo',
#  'Manchester United',
#  'FWA, FPY, YPY, PPS',
#  '[26]',
#  '2007–08',
#  'Cristiano Ronaldo (2)',
#  'Manchester United',
#  'FWA, FPY, PPS',
#  '[27]',
#  '2008–09',
#  'Ryan Giggs',
#  'Manchester United',
#  '[28]',
#  '2009–10',
#  'Wayne Rooney',
#  'Manchester United',
#  'FWA, FPY, PPS',
#  '[11]',
#  '2010–11',
#  'Gareth Bale',
#  'Tottenham Hotspur',
#  '[29]',
#  '2011–12',
#  'Robin van Persie',
#  'Arsenal',
#  'FWA, FPY',
#  '[30]',
#  '2012–13',
#  'Gareth Bale (2)',
#  'Tottenham Hotspur',
#  'FWA, YPY, PPS',
#  '[31]',
#  '2013–14',
#  'Luis Suárez',
#  'Liverpool',
#  'FWA, FPY, PPS, FSF',
#  '[32]',
#  '2014–15',
#  'Eden Hazard',
#  'Chelsea',
#  'FWA, PPS',
#  '[33]',
#  '2015–16',
#  'Riyad Mahrez',
#  'Leicester City',
#  'FPY',
#  '[34]',
#  '2016–17',
#  "N'Golo Kanté",
#  'Chelsea',
#  'FWA, PPS',
#  '[35]',
#  '2017–18',
#  'Mohamed Salah',
#  'Liverpool',
#  'FWA, FPY, PPS, FSF',
#  '[36]',
#  '2018–19',
#  'Virgil van Dijk',
#  'Liverpool',
#  'PPS, FSF',
#  '[37]',
#  '2019–20',
#  'Kevin De Bruyne',
#  'Manchester City',
#  'PPS',
#  '[38]',
#  '2020–21',
#  'Kevin De Bruyne (2)',
#  'Manchester City']

# %%
fullData = []
i = 0
while i < len(to_use):
    print(to_use[i])
    if to_use[i][:2] == '19'or to_use[i][:2] == '20':
        vector.append(to_use[i])
        vector.append(to_use[i+1])
        i += 1
    fullData.append(vector)
    i += 1
# Out:
# Winners of the PFA Players' of the Year
# Year
# Player
# Club
# Also won
# Notes
# 1973–74
# Leeds United
# 1974–75
# Derby County
# 1975–76
# Tottenham Hotspur
# [17]
# 1976–77
# Aston Villa
# YPY
# [18]
# 1977–78
# Nottingham Forest
# 1978–79
# Arsenal
# [19]
# 1979–80
# Liverpool
# FWA
# [20]
# 1980–81
# Ipswich Town
# 1981–82
# Southampton
# 1982–83
# Liverpool
# FWA
# 1983–84
# Liverpool
# FWA
# 1984–85
# Everton
# 1985–86
# Everton
# FWA
# 1986–87
# Tottenham Hotspur
# FWA
# 1987–88
# Liverpool
# FWA
# 1988–89
# Manchester United
# 1989–90
# Aston Villa
# 1990–91
# Manchester United
# [21]
# 1991–92
# Manchester United
# 1992–93
# Aston Villa
# 1993–94
# Manchester United
# [22]
# 1994–95
# Blackburn Rovers
# PPS
# 1995–96
# Newcastle United
# 1996–97
# Newcastle United
# [23]
# 1997–98
# Arsenal
# FWA
# 1998–99
# Tottenham Hotspur
# FWA
# 1999–2000
# Manchester United
# FWA
# 2000–01
# Manchester United
# FWA
# 2001–02
# Manchester United
# FPY
# 2002–03
# Arsenal
# FWA, FPY
# [24]
# 2003–04
# Arsenal
# FWA, FPY, PPS
# [25]
# 2004–05
# Chelsea
# 2005–06
# Liverpool
# 2006–07
# Manchester United
# FWA, FPY, YPY, PPS
# [26]
# 2007–08
# Manchester United
# FWA, FPY, PPS
# [27]
# 2008–09
# Manchester United
# [28]
# 2009–10
# Manchester United
# FWA, FPY, PPS
# [11]
# 2010–11
# Tottenham Hotspur
# [29]
# 2011–12
# Arsenal
# FWA, FPY
# [30]
# 2012–13
# Tottenham Hotspur
# FWA, YPY, PPS
# [31]
# 2013–14
# Liverpool
# FWA, FPY, PPS, FSF
# [32]
# 2014–15
# Chelsea
# FWA, PPS
# [33]
# 2015–16
# Leicester City
# FPY
# [34]
# 2016–17
# Chelsea
# FWA, PPS
# [35]
# 2017–18
# Liverpool
# FWA, FPY, PPS, FSF
# [36]
# 2018–19
# Liverpool
# PPS, FSF
# [37]
# 2019–20
# Manchester City
# PPS
# [38]
# 2020–21
# Manchester City

# %%
data = fullData[1]
data = data[:96]
year = data[::2]
player = data[1::2]

# %%
formated = []
for don in year:
    
    if don[:2] == '20': 
        don = don.replace('–','/')
        don = don[:5] + '20' + don[5:]
        formated.append(don)
    else: 
        formated.append(don)

# %%
formated
# Out:
# ['1973–74',
#  '1974–75',
#  '1975–76',
#  '1976–77',
#  '1977–78',
#  '1978–79',
#  '1979–80',
#  '1980–81',
#  '1981–82',
#  '1982–83',
#  '1983–84',
#  '1984–85',
#  '1985–86',
#  '1986–87',
#  '1987–88',
#  '1988–89',
#  '1989–90',
#  '1990–91',
#  '1991–92',
#  '1992–93',
#  '1993–94',
#  '1994–95',
#  '1995–96',
#  '1996–97',
#  '1997–98',
#  '1998–99',
#  '1999–2000',
#  '2000/2001',
#  '2001/2002',
#  '2002/2003',
#  '2003/2004',
#  '2004/2005',
#  '2005/2006',
#  '2006/2007',
#  '2007/2008',
#  '2008/2009',
#  '2009/2010',
#  '2010/2011',
#  '2011/2012',
#  '2012/2013',
#  '2013/2014',
#  '2014/2015',
#  '2015/2016',
#  '2016/2017',
#  '2017/2018',
#  '2018/2019',
#  '2019/2020',
#  '2020/2021']

# %%
player
# Out:
# ['Norman Hunter',
#  'Colin Todd',
#  'Pat Jennings',
#  'Andy Gray',
#  'Peter Shilton',
#  'Liam Brady',
#  'Terry McDermott',
#  'John Wark',
#  'Kevin Keegan',
#  'Kenny Dalglish',
#  'Ian Rush',
#  'Peter Reid',
#  'Gary Lineker',
#  'Clive Allen',
#  'John Barnes',
#  'Mark Hughes',
#  'David Platt',
#  'Mark Hughes (2)',
#  'Gary Pallister',
#  'Paul McGrath',
#  'Eric Cantona',
#  'Alan Shearer',
#  'Les Ferdinand',
#  'Alan Shearer (2)',
#  'Dennis Bergkamp',
#  'David Ginola',
#  'Roy Keane',
#  'Teddy Sheringham',
#  'Ruud van Nistelrooy',
#  'Thierry Henry',
#  'Thierry Henry (2)',
#  'John Terry',
#  'Steven Gerrard',
#  'Cristiano Ronaldo',
#  'Cristiano Ronaldo (2)',
#  'Ryan Giggs',
#  'Wayne Rooney',
#  'Gareth Bale',
#  'Robin van Persie',
#  'Gareth Bale (2)',
#  'Luis Suárez',
#  'Eden Hazard',
#  'Riyad Mahrez',
#  "N'Golo Kanté",
#  'Mohamed Salah',
#  'Virgil van Dijk',
#  'Kevin De Bruyne',
#  'Kevin De Bruyne (2)']

# %%
df = pd.Dataframe(year,player)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-131-182457135dd2> in <module>
# ----> 1 df = pd.Dataframe(year,player)
#
# ~\anaconda3\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     261             return _SparseArray
#     262
# --> 263         raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     264
#     265
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'
