# %%
import numpy as np 
import pandas as pd
import glob
import os
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Full Dataset (league standings with players stats).csv')

# %%
df = df.drop(df.filter(like = 'Unn'), axis = 1)

# %%
pd.set_option('display.max_columns', None)

# %%
df
# Out:
#           id                firstname         lastname   age  \
# 0      18241                     Mark           Yeates  36.0
# 1      19153                   Gareth            Barry  39.0
# 2      19203                   Ashley             Cole  41.0
# 3      19417                     Liam        Ridgewell  37.0
# 4      50978                   Justin            Hoyte  36.0
# ...      ...                      ...              ...   ...
# 10764     17                Christian          Pulisic  24.0
# 10765    890  Faustino Marcos Alberto             Rojo  32.0
# 10766   2294                  Willian  Borges da Silva  34.0
# 10767  18897          DeAndre Roselle           Yedlin  29.0
# 10768  19549                  Antonee         Robinson  25.0
#
#                nationality  height weight  injured  teamID          teamname  \
# 0      Republic of Ireland  175 cm  66 kg    False      47  TottenhamHotspur
# 1                  England  183 cm  78 kg    False      66        AstonVilla
# 2                  England  176 cm  66 kg    False      42           Arsenal
# 3                  England  188 cm  77 kg    False      66        AstonVilla
# 4      Trinidad and Tobago  180 cm  68 kg    False      42           Arsenal
# ...                    ...     ...    ...      ...     ...               ...
# 10764                  USA  172 cm  69 kg    False      49           Chelsea
# 10765            Argentina  187 cm  85 kg    False      33  ManchesterUnited
# 10766               Brazil  175 cm  77 kg    False      42           Arsenal
# 10767                  USA  172 cm  75 kg    False      34   NewcastleUnited
# 10768                  USA  176 cm  70 kg    False      36            Fulham
#
#        appearences  lineups  minutes    position    rating  captain  subIn  \
# 0              0.0      0.0      0.0  Midfielder       NaN    False    0.0
# 1              1.0      1.0     90.0  Midfielder       NaN    False    0.0
# 2              2.0      2.0    180.0    Defender       NaN    False    0.0
# 3              0.0      0.0      0.0    Defender       NaN    False    0.0
# 4              1.0      0.0      1.0    Defender       NaN    False    1.0
# ...            ...      ...      ...         ...       ...      ...    ...
# 10764         27.0     18.0   1735.0  Midfielder  6.842307    False    9.0
# 10765          0.0      0.0      0.0    Defender       NaN    False    0.0
# 10766         25.0     16.0   1406.0    Attacker  7.004000    False    9.0
# 10767          6.0      5.0    437.0    Defender  6.516666    False    1.0
# 10768         28.0     24.0   2161.0    Defender  6.882142    False    4.0
#
#        subOut  bench  totalShots  shotsOn  totalGoals  goalsConceded  \
# 0         0.0    1.0         NaN      NaN         0.0            NaN
# 1         0.0    0.0         NaN      NaN         0.0            NaN
# 2         0.0    0.0         NaN      NaN         0.0            NaN
# 3         0.0    1.0         NaN      NaN         0.0            NaN
# 4         0.0    1.0         NaN      NaN         0.0            NaN
# ...       ...    ...         ...      ...         ...            ...
# 10764     6.0   11.0        32.0     16.0         4.0            0.0
# 10765     0.0    0.0         NaN      NaN         0.0            NaN
# 10766    10.0   17.0        13.0      3.0         1.0            0.0
# 10767     2.0    4.0         1.0      NaN         0.0            0.0
# 10768     2.0    7.0         6.0      4.0         0.0            0.0
#
#        goalAssists  goalSaves  totalPasses  keyPasses  passAccuracy  \
# 0              NaN        NaN          NaN        NaN           NaN
# 1              NaN        NaN          NaN        NaN           NaN
# 2              NaN        NaN          NaN        NaN           NaN
# 3              NaN        NaN          NaN        NaN           NaN
# 4              NaN        NaN          NaN        NaN           NaN
# ...            ...        ...          ...        ...           ...
# 10764          2.0        NaN        662.0       26.0          20.0
# 10765          NaN        NaN          NaN        NaN           NaN
# 10766          5.0        NaN        677.0       32.0          23.0
# 10767          NaN        NaN        135.0        3.0          17.0
# 10768          NaN        NaN       1047.0       30.0          29.0
#
#        totalTackles  blocks  interceptions  duelsTotal  duelsWon  \
# 0               NaN     NaN            NaN         NaN       NaN
# 1               NaN     NaN            NaN         NaN       NaN
# 2               NaN     NaN            NaN         NaN       NaN
# 3               NaN     NaN            NaN         NaN       NaN
# 4               NaN     NaN            NaN         NaN       NaN
# ...             ...     ...            ...         ...       ...
# 10764          19.0     2.0           12.0       276.0     120.0
# 10765           NaN     NaN            NaN         NaN       NaN
# 10766          13.0     NaN            8.0       106.0      56.0
# 10767           9.0     1.0            7.0        31.0      18.0
# 10768          45.0     4.0           37.0       239.0     140.0
#
#        dribbleAttempts  dribblesSuccess  dribblesPast  foulsDrawn  \
# 0                  NaN              NaN           NaN         NaN
# 1                  NaN              NaN           NaN         NaN
# 2                  NaN              NaN           NaN         NaN
# 3                  NaN              NaN           NaN         NaN
# 4                  NaN              NaN           NaN         NaN
# ...                ...              ...           ...         ...
# 10764            108.0             49.0           NaN        33.0
# 10765              NaN              NaN           NaN         NaN
# 10766             18.0             13.0           NaN        21.0
# 10767              2.0              1.0           NaN         4.0
# 10768             73.0             51.0           NaN         8.0
#
#        foulsCommitted  cardsYel  cardsYelRed  cardsRed  penaltyWon  \
# 0                 NaN       0.0          0.0       0.0         NaN
# 1                 NaN       0.0          0.0       0.0         NaN
# 2                 NaN       0.0          0.0       0.0         NaN
# 3                 NaN       0.0          0.0       0.0         NaN
# 4                 NaN       0.0          0.0       0.0         NaN
# ...               ...       ...          ...       ...         ...
# 10764            13.0       2.0          0.0       0.0         NaN
# 10765             NaN       0.0          0.0       0.0         NaN
# 10766             5.0       0.0          0.0       0.0         NaN
# 10767             4.0       0.0          0.0       0.0         NaN
# 10768            20.0       4.0          0.0       1.0         NaN
#
#        penaltyCommited  penaltyScored  penaltyMissed  penaltySaved season  \
# 0                  NaN            NaN            NaN           NaN  02/03
# 1                  NaN            NaN            NaN           NaN  02/03
# 2                  NaN            NaN            NaN           NaN  02/03
# 3                  NaN            NaN            NaN           NaN  02/03
# 4                  NaN            NaN            NaN           NaN  02/03
# ...                ...            ...            ...           ...    ...
# 10764              NaN            0.0            0.0           NaN  20/21
# 10765              NaN            NaN            NaN           NaN  20/21
# 10766              NaN            0.0            0.0           NaN  20/21
# 10767              NaN            0.0            0.0           NaN  20/21
# 10768              NaN            0.0            0.0           NaN  20/21
#
#                       name  Standings  Played  Wins  Draw  Lost  GoalsFor  \
# 0            Thierry Henry        NaN     NaN   NaN   NaN   NaN       NaN
# 1            Thierry Henry        NaN     NaN   NaN   NaN   NaN       NaN
# 2            Thierry Henry        NaN     NaN   NaN   NaN   NaN       NaN
# 3            Thierry Henry        NaN     NaN   NaN   NaN   NaN       NaN
# 4            Thierry Henry        NaN     NaN   NaN   NaN   NaN       NaN
# ...                    ...        ...     ...   ...   ...   ...       ...
# 10764  Kevin De Bruyne (2)        4.0    38.0  19.0  10.0   9.0      58.0
# 10765  Kevin De Bruyne (2)        2.0    38.0  21.0  11.0   6.0      73.0
# 10766  Kevin De Bruyne (2)        8.0    38.0  18.0   7.0  13.0      55.0
# 10767  Kevin De Bruyne (2)       12.0    38.0  12.0   9.0  17.0      46.0
# 10768  Kevin De Bruyne (2)       18.0    38.0   5.0  13.0  20.0      27.0
#
#        GoalsAgainst  GoalDifference  Points
# 0               NaN             NaN     NaN
# 1               NaN             NaN     NaN
# 2               NaN             NaN     NaN
# 3               NaN             NaN     NaN
# 4               NaN             NaN     NaN
# ...             ...             ...     ...
# 10764          36.0            22.0    67.0
# 10765          44.0            29.0    74.0
# 10766          39.0            16.0    61.0
# 10767          62.0           -16.0    45.0
# 10768          53.0           -26.0    28.0
#
# [10769 rows x 57 columns]

# %%
#Check goals
cols = ['totalGoals','passAccuracy','totalTackles','totalPasses']
for col in cols: 
    fig, ax = plt.subplots(figsize=(12, 12))
    sns.barplot(data=df, x='season', y=col, ax = ax).set_title(str(col) + ' by season')
