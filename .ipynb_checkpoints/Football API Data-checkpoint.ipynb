# %%
import requests
import pandas as pd
import numpy as np

# %%
#This is first running, season 2021, page 1
#Implement for loop to query data from previous years and more pages

#Use this API : Players statistics by league id
import requests

url = "https://api-football-v1.p.rapidapi.com/v3/players"

querystring = {"league":"39","season":"2021","page":"1"}

headers = {
    "X-RapidAPI-Host": "api-football-v1.p.rapidapi.com",
    "X-RapidAPI-Key": "d356c39fe7mshf3ec31c0312f244p17df85jsn2bc9fd933f3f"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response)
# Out:
# <Response [200]>

# %%
import json
#from jsontraverse.parser import JsonTraverseParser
data = response.json()
data
# Out:
# {'get': 'players',
#  'parameters': {'league': '39', 'page': '1', 'season': '2021'},
#  'errors': [],
#  'results': 20,
#  'paging': {'current': 1, 'total': 39},
#  'response': [{'player': {'id': 84,
#     'name': 'Wesley Moraes',
#     'firstname': 'Wesley',
#     'lastname': 'Moraes Ferreira da Silva',
#     'age': 26,
#     'birth': {'date': '1996-11-26',
#      'place': 'Juiz de Fora',
#      'country': 'Brazil'},
#     'nationality': 'Brazil',
#     'height': '191 cm',
#     'weight': '93 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/84.png'},
#    'statistics': [{'team': {'id': 66,
#       'name': 'Aston Villa',
#       'logo': 'https://media.api-sports.io/football/teams/66.png'},
#      'league': {'id': 39,
#       'name': 'Premier League',
#       'country': 'England',
#       'logo': 'https://media.api-sports.io/football/leagues/39.png',
#       'flag': 'https://media.api-sports.io/flags/gb.svg',
#       'season': 2021},
# ...

# %%
#TODO
#Run a query that get data for 2019 to 2020 and pages 1 to 34 
#That would be a total of 100 requests limit and will have 50% of the data I seek
tab = []
for i in range(38):
    querystring = {"league":"39","season":"2020","page":str(i)}
    tab.append(querystring)

print(tab)
# Out:
# [{'league': '39', 'season': '2020', 'page': '0'}, {'league': '39', 'season': '2020', 'page': '1'}, {'league': '39', 'season': '2020', 'page': '2'}, {'league': '39', 'season': '2020', 'page': '3'}, {'league': '39', 'season': '2020', 'page': '4'}, {'league': '39', 'season': '2020', 'page': '5'}, {'league': '39', 'season': '2020', 'page': '6'}, {'league': '39', 'season': '2020', 'page': '7'}, {'league': '39', 'season': '2020', 'page': '8'}, {'league': '39', 'season': '2020', 'page': '9'}, {'league': '39', 'season': '2020', 'page': '10'}, {'league': '39', 'season': '2020', 'page': '11'}, {'league': '39', 'season': '2020', 'page': '12'}, {'league': '39', 'season': '2020', 'page': '13'}, {'league': '39', 'season': '2020', 'page': '14'}, {'league': '39', 'season': '2020', 'page': '15'}, {'league': '39', 'season': '2020', 'page': '16'}, {'league': '39', 'season': '2020', 'page': '17'}, {'league': '39', 'season': '2020', 'page': '18'}, {'league': '39', 'season': '2020', 'page': '19'}, {'leagu
# ...

# %%
#Query all data from 2020 
data2020=[]
for i in range(38):
    url = "https://api-football-v1.p.rapidapi.com/v3/players"

    querystring = {"league":"39","season":"2020","page":str(i)}

    headers = {
        "X-RapidAPI-Host": "api-football-v1.p.rapidapi.com",
        "X-RapidAPI-Key": "d356c39fe7mshf3ec31c0312f244p17df85jsn2bc9fd933f3f"
    }

    response = requests.request("GET", url, headers=headers, params=querystring)
    
    data2020.append(response.text)
    
data2020
#Good but have to pop last 9 pages(so from 28 and 37 inclusively , didn't work because exceeded rate per minute)
# Out:
# ['{"get":"players","parameters":{"league":"39","page":"0","season":"2020"},"errors":[],"results":0,"paging":{"current":0,"total":37},"response":[]}',
# ...

# %%
data2020 = data2020[0:29]
data2020
# Out:
# ['{"get":"players","parameters":{"league":"39","page":"0","season":"2020"},"errors":[],"results":0,"paging":{"current":0,"total":37},"response":[]}',
# ...

# %%
#complete 2020 array
for i in range(29,38):
    url = "https://api-football-v1.p.rapidapi.com/v3/players"

    querystring = {"league":"39","season":"2020","page":str(i)}

    headers = {
        "X-RapidAPI-Host": "api-football-v1.p.rapidapi.com",
        "X-RapidAPI-Key": "d356c39fe7mshf3ec31c0312f244p17df85jsn2bc9fd933f3f"
    }

    response = requests.request("GET", url, headers=headers, params=querystring)
    
    data2020.append(response.text)
    
data2020
# Out:
# ['{"get":"players","parameters":{"league":"39","page":"0","season":"2020"},"errors":[],"results":0,"paging":{"current":0,"total":37},"response":[]}',
# ...

# %%
from json import loads
#Data2020 is complete, next step is to decide how to model and keep which part of the data
#data2020Json = list(map(lambda i: data2020[i].json(),data2020))
tableau=[]
for i in range(38):
    tableau.append(i)
#Format data to json
jsonData2020=list(map(lambda i: loads(data2020[i]),tableau))
jsonData2020[37]
# Out:
# {'get': 'players',
#  'parameters': {'league': '39', 'page': '37', 'season': '2020'},
#  'errors': [],
#  'results': 5,
#  'paging': {'current': 37, 'total': 37},
#  'response': [{'player': {'id': 17,
#     'name': 'C. Pulisic',
#     'firstname': 'Christian',
#     'lastname': 'Pulisic',
#     'age': 24,
#     'birth': {'date': '1998-09-18', 'place': 'Hershey', 'country': 'USA'},
#     'nationality': 'USA',
#     'height': '172 cm',
#     'weight': '69 kg',
#     'injured': False,
#     'photo': 'https://media.api-sports.io/football/players/17.png'},
#    'statistics': [{'team': {'id': 49,
#       'name': 'Chelsea',
#       'logo': 'https://media.api-sports.io/football/teams/49.png'},
#      'league': {'id': 39,
#       'name': 'Premier League',
#       'country': 'England',
#       'logo': 'https://media.api-sports.io/football/leagues/39.png',
#       'flag': 'https://media.api-sports.io/flags/gb.svg',
#       'season': 2020},
#      'games': {'appearences': 27,
# ...

# %%
#Use model below to pick and chose 
print(jsonData2020[30]['response'][5]['player']['id'])
# Out:
# 2999

# %%
#Create prototype array which will be column names in the df
proto= ["id"\
, "firstname"\
, "lastname"\
, "age"\
, "nationality"\
, "height"\
, "weight"\
, "injured"\
, "teamID"\
, "teamname"\
, "appearences"\
, "lineups"\
, "minutes"\
, "position"\
, "rating"\
, "captain"\
, "subIn"\
, "subOut"\
, "bench"\
, "totalShots"\
, "shotsOn"\
, "totalGoals"\
, "goalsConceded"\
, "goalAssists"\
, "goalSaves"\
, "totalPasses"\
, "keyPasses"\
, "passAccuracy"\
, "totalTackles"\
, "blocks"\
, "interceptions"\
, "duelsTotal"\
, "duelsWon"\
, "dribbleAttempts"\
, "dribblesSuccess"\
, "dribblesPast"\
, "foulsDrawn"\
, "foulsCommitted"\
, "cardsYel"\
, "cardsYelRed"\
, "cardsRed"\
, "penaltyWon"\
, "penaltyCommited"\
, "penaltyScored"\
, "penaltyMissed"\
, "penaltySaved"]
# Out:
# 47

# %%
#code to create record of a player
# under the player dict
#Structure looks like this data[pageNum(1 to n)][response][player index 0 to 19][player or stats]
#[if player, value, else dict][value]
ID = jsonData2020[1]['response'][0]['player']['id']
firstName = jsonData2020[1]['response'][0]['player']['firstname']
lastName = jsonData2020[1]['response'][0]['player']['lastname']
age = jsonData2020[1]['response'][0]['player']['age']
nationality = jsonData2020[1]['response'][0]['player']['nationality'] 
height = jsonData2020[1]['response'][0]['player']['height']
weight = jsonData2020[1]['response'][0]['player']['weight']
injured = jsonData2020[1]['response'][0]['player']['injured']

#under the stats dict
teamID = jsonData2020[1]['response'][0]['statistics'][0]['team']['id']
teamName = jsonData2020[1]['response'][0]['statistics'][0]['team']['name']
appearences = jsonData2020[1]['response'][0]['statistics'][0]['games']['appearences']
lineups = jsonData2020[1]['response'][0]['statistics'][0]['games']['lineups']
minutes = jsonData2020[1]['response'][0]['statistics'][0]['games']['minutes']
position = jsonData2020[1]['response'][0]['statistics'][0]['games']['position']
rating = jsonData2020[1]['response'][0]['statistics'][0]['games']['rating']
captain = jsonData2020[1]['response'][0]['statistics'][0]['games']['captain']
subIn = jsonData2020[1]['response'][0]['statistics'][0]['substitutes']['in']
subOut = jsonData2020[1]['response'][0]['statistics'][0]['substitutes']['out']
bench = jsonData2020[1]['response'][0]['statistics'][0]['substitutes']['bench']
shotsTotal = jsonData2020[1]['response'][0]['statistics'][0]['shots']['total']
shotsOn = jsonData2020[1]['response'][0]['statistics'][0]['shots']['on']
goalsTotal = jsonData2020[1]['response'][0]['statistics'][0]['goals']['total']
goalsConceded = jsonData2020[1]['response'][0]['statistics'][0]['goals']['conceded']
goalsAssists = jsonData2020[1]['response'][0]['statistics'][0]['goals']['assists']
goalsSaves = jsonData2020[1]['response'][0]['statistics'][0]['goals']['saves']
passesTotal = jsonData2020[1]['response'][0]['statistics'][0]['passes']['total']
passesKey = jsonData2020[1]['response'][0]['statistics'][0]['passes']['key']
passesAccuracy = jsonData2020[1]['response'][0]['statistics'][0]['passes']['accuracy']
tacklesTotal = jsonData2020[1]['response'][0]['statistics'][0]['tackles']['total']
blocks = jsonData2020[1]['response'][0]['statistics'][0]['tackles']['blocks']
interceptions = jsonData2020[1]['response'][0]['statistics'][0]['tackles']['interceptions']
duelsTotal = jsonData2020[1]['response'][0]['statistics'][0]['duels']['total']
duelsWon = jsonData2020[1]['response'][0]['statistics'][0]['duels']['won']
dribbleAttempts = jsonData2020[1]['response'][0]['statistics'][0]['dribbles']['attempts']
dribbleSuccess = jsonData2020[1]['response'][0]['statistics'][0]['dribbles']['success']
dribblesPast = jsonData2020[1]['response'][0]['statistics'][0]['dribbles']['past']
foulsDrawn = jsonData2020[1]['response'][0]['statistics'][0]['fouls']['drawn']
foulsCommitted = jsonData2020[1]['response'][0]['statistics'][0]['fouls']['committed']
cardsYel = jsonData2020[1]['response'][0]['statistics'][0]['cards']['yellow']
cardsYelRed = jsonData2020[1]['response'][0]['statistics'][0]['cards']['yellowred']
cardsRed = jsonData2020[1]['response'][0]['statistics'][0]['cards']['red']
penaltyWon = jsonData2020[1]['response'][0]['statistics'][0]['penalty']['won']
penaltyCommitted = jsonData2020[1]['response'][0]['statistics'][0]['penalty']['commited']
penaltyScored = jsonData2020[1]['response'][0]['statistics'][0]['penalty']['scored']
penaltyMissed = jsonData2020[1]['response'][0]['statistics'][0]['penalty']['missed']
penaltySaved = jsonData2020[1]['response'][0]['statistics'][0]['penalty']['saved']

print(penaltyMissed)
# Out:
# 1

# %%
finalArr = []
#Keys to iterate through
playerKeys = ['id', 'firstname', 'lastname', 'age', 'nationality', 'height', 'weight', 'injured']
teamKeys = ['id','name']
gamesKeys = ['appearences','lineups','minutes','position','rating','captain']
subKeys = ['in','out','bench']
shotsKeys = ['total','on']
goalsKeys = ['total','conceded','assists','saves']
passesKeys = ['total','key','accuracy']
tackKeys = ['total','blocks','interceptions']
duelsKeys = ['total','won']
dribKeys = ['attempts','success','past']
foulsKeys = ['drawn','committed']
cardsKeys = ['yellow','yellowred','red']
penalKeys = ['won','commited','scored','missed','saved']

#Create a dict to optimize code

iterable=0
for i in range(1,38):
    #To adjust for the last page
    if i == 37: 
        iterable = 5
    else:
        iterable = 20
        
    for j in range(iterable):
        to_fill = []
        for pkey in playerKeys:
            to_fill.append(jsonData2020[i]['response'][j]['player'][pkey])
        for tkey in teamKeys:
            to_fill.append(jsonData2020[i]['response'][j]['statistics'][0]['team'][tkey])
        for gkey in gamesKeys: 
            to_fill.append(jsonData2020[i]['response'][j]['statistics'][0]['games'][gkey])
        for subkey in subKeys: 
            to_fill.append(jsonData2020[i]['response'][j]['statistics'][0]['substitutes'][subkey])
        for skey in shotsKeys:
            to_fill.append(jsonData2020[i]['response'][j]['statistics'][0]['shots'][skey])
        for goalkey in goalsKeys: 
            to_fill.append(jsonData2020[i]['response'][j]['statistics'][0]['goals'][goalkey])
        for passkey in passesKeys: 
            to_fill.append(jsonData2020[i]['response'][j]['statistics'][0]['passes'][passkey])
        for takey in tackKeys: 
            to_fill.append(jsonData2020[i]['response'][j]['statistics'][0]['tackles'][takey])
        for dkey in duelsKeys: 
            to_fill.append(jsonData2020[i]['response'][j]['statistics'][0]['duels'][dkey])
        for dribkey in dribKeys: 
            to_fill.append(jsonData2020[i]['response'][j]['statistics'][0]['dribbles'][dribkey])
        for fkey in foulsKeys:
            to_fill.append(jsonData2020[i]['response'][j]['statistics'][0]['fouls'][fkey])
        for ckey in cardsKeys: 
            to_fill.append(jsonData2020[i]['response'][j]['statistics'][0]['cards'][ckey])
        for penkey in penalKeys: 
            to_fill.append(jsonData2020[i]['response'][j]['statistics'][0]['penalty'][penkey])
        
        finalArr.append(to_fill)

# %%
finalArr[300]
# Out:
# [1469,
#  'Daniel Nii',
#  'Tackie Mensah Welbeck',
#  32,
#  'England',
#  '185 cm',
#  '73 kg',
#  False,
#  51,
#  'Brighton',
#  24,
#  17,
#  1546,
#  'Attacker',
#  '6.791666',
#  False,
#  7,
#  10,
#  9,
#  26,
#  15,
#  6,
#  0,
#  1,
#  None,
#  260,
#  22,
#  9,
#  12,
#  None,
#  7,
#  168,
#  68,
#  33,
#  18,
#  None,
#  17,
#  19,
#  0,
#  0,
#  0,
#  None,
#  None,
#  0,
#  1,
#  None]

# %%
#TO NOTE: Year in query is season XXXX/XXXX+1
#Example if 2020 is past as param, the data returned is from the season 2020/2021
